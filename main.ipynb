# %%
! pip install torch scipy torchvision tqdm visdom setproctitle absl-py
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:053504fc-5a36-4e4f-9b9f-c19bc5c3e788
